# %%
from user import *

# %%
a = User ()

# %%
a.login ("Bagus")

# %%
a.check_plan ()
# Out:
# User Bagus sedang berlangganan
# Basic Plan            Services
# --------------------  -----------------
# True                  Bisa Stream
# True                  Bisa Download
# True                  Kualitas SD
# False                 Kualitas HD
# False                 Kualitas UHD
# 1                     Number of Devices
# 3rd party Movie only  Jenis Konten
# 120000                Harga

# %%
a.upgrade_plan ("Standard Plan")
# Out:
# Harga yang harus dibayarkan untuk upgrade ke Standard Plan adalah Rp.160000

# %%
a.check_plan ()
# Out:
# User Bagus sedang berlangganan
# Standard Plan                Services
# ---------------------------  -----------------
# True                         Bisa Stream
# True                         Bisa Download
# True                         Kualitas SD
# True                         Kualitas HD
# False                        Kualitas UHD
# 2                            Number of Devices
# Basic Plan Content + Sports  Jenis Konten
# 160000                       Harga
